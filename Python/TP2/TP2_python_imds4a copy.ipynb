# %% [markdown]
# # TP 2 : Classes et Objets
#
# ## 1. Le guessing game
#
# On veut coder dans l'esprit orienté objét, le jeu qui consiste à deviner un nombre. Un tel jeu possède :
#  - un joueur
#  - un nombre secret
#  - un statut (False ou True) selon que le jeu est résolu ou non.
#
# Un joueur a un nom et peut _deviner_ un nombre.
#
# Coder une classe ```Player``` qui initialise le nom du joueur et propose une méthode ```guess``` pour deviner un nombre.
#
# Coder une classe ```Game``` qui initialise un jeu pour un joueur donné et qui propose une méthode ```tryGuess``` qui récupère le guess du joueur et répond si la valeur est plus ou moins élevée.

# %%
from numpy.random import randint

class Player(object) :
    """create a player with his name and a guess method"""

    def __init__(self, name) -> None:
        self.__name = name
    
    def name(self) :
        return self.__name

    def guess(self) :
        nb = int(input("Try to guess the number which is between 0 and 100 :"))
        return nb

class Game(object) :
    "Initialize the game and allow user to try guessing the right number"

    def __init__(self, player) -> None:
        self.player = player
        self.__rand_nb = randint(0, 100)
        self.__status = False

    def tryGuess(self) :
        nb = self.player.guess()
        if nb == self.__rand_nb :
            self.__status = True
            print(f"Bravo {self.player.name()} tu as gagné !")
        elif nb > self.__rand_nb :
            print("Trop grand !")
        else :
            print("Trop petit !")

    def run(self) :
        while not(self.__status) :
            self.tryGuess()

# %%
moi = Player("Laurent Beaudou")
monJeu = Game(moi)
monJeu.run()
# Out:
# 49
# Bravo Laurent Beaudou tu as gagné !

# %% [markdown]
# Supposons que l'on veuille distinguer les joueurs humains (nécessite une interaction graphique) des bots.
#
# On va remplacer la classe ```Player``` par une classe abstraite et lui donner deux classes en héritage:
#  - la classe ```HumanPlayer```
#  - la classe ```CompPlayer```
#
#  Cette dernière aura des attributs supplémentaires (liste des essais tentés, liste des resultats obtenus). On lui ajoutera également une méthode ```update_results``` qui mettra à jour les résultats des tentatives.
#
#  Il conviendra de modifier un tant soit peu la classe ```Game``` pour lancer la méthode spécifique après les essais de l'ordinateur (cf méthode ```isinstance()```).

# %%
from abc import ABC, abstractmethod
from random import randint

class Player(ABC) :

    def __init__(self, name) -> None:
        self.__name = name

    def name(self) :
        return self.__name
    
    @abstractmethod
    def Guess(self) :
        pass
    
class CompPlayer(Player) :

    IdComp = 0

    def __init__(self, GuessMethod) -> None:
        super().__init__(f"Comp#{CompPlayer.IdComp}")
        self.GuessMethod = GuessMethod
        CompPlayer.IdComp += 1
        self.low = 0
        self.high = 1000000

    def updateHigh(self, high) :
        self.high = high
    
    def Guess(self):
        return self.GuessMethod(self.low, self.high)
    
    def updateGuess(self, nb, ans) :
        if ans == 1 :
            self.low = nb
        else :
            self.high = nb
    
class Game(object) :

    def __init__(self, player1, player2, max) -> None:
        self.player1 = player1
        self.player2 = player2
        self.__rand_nb = randint(0, max)
        self.__status = False
        for p in [self.player1, self.player2] :
            if isinstance(p, CompPlayer) :
                p.updateHigh(max)

    def turnPlayer(self) :
        p = self.player1
        self.player1 = self.player2
        self.player2 = p
        print(str(self.player1.name()) + "\'s turn")

    def tryGuess(self) :
        nb = self.player1.Guess()
        print(str(self.player1.name())+" plays value "+str(nb)+".")
        if nb == self.__rand_nb :
            self.__status = True
            print(f"Bravo {self.player1.name()}, c'est gagné !")
            ans = 0
        elif nb > self.__rand_nb :
            print("Trop grand !")
            ans = -1
            self.turnPlayer()
        else :
            print("Trop petit !")
            ans = 1
            self.turnPlayer()

        for p in [self.player1, self.player2] :
            if isinstance(p, CompPlayer) :
                p.updateGuess(nb, ans)

    def run(self) :
        while not(self.__status) :
            self.tryGuess()

# %% [markdown]
# Mieux, on veut faire jouer les gens les uns contre les autres. Les guess sont publics, et il est obligatoire de réduire l'intervalle. Proposer différentes fonctions.
#
# Réécrire la classe ```ComputerPlayer``` pour qu'elle prenne une fonction en arguement qui lui servira de méthode de guess.
#
# Organiser un immense tournoi de vos IA !

# %%
def randomPick(low, up):
    return randint(low, up)

def dicho(low,up):
    return int((low+up)/2)

def byOne(low,up):
    return low+1

# %%
cp = 0
cq = 0
for _ in range(100):
    p = CompPlayer(byOne)
    q = CompPlayer(dicho)
    g = Game(p,q,1000)
    z = g.run()
    if z == p: cp += 1
    else: cq += 1
print("byOne : "+str(cp)+", dicho : "+str(cq))
# Out:
# Comp#0 plays value 1.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 500.
# Trop grand !
# Comp#0's turn
# Comp#0 plays value 2.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 251.
# Trop grand !
# Comp#0's turn
# Comp#0 plays value 3.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 127.
# Trop grand !
# Comp#0's turn
# Comp#0 plays value 4.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 65.
# Trop grand !
# Comp#0's turn
# Comp#0 plays value 5.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 35.
# Trop grand !
# Comp#0's turn
# Comp#0 plays value 6.
# Trop petit !
# Comp#1's turn
# Comp#1 plays value 20.
# Trop petit !
# Comp#0's turn
# Comp#0 plays value 21.
# Bravo Comp#0, c'est gagné !
# Comp#2 plays value 1.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 500.
# Trop grand !
# Comp#2's turn
# Comp#2 plays value 2.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 251.
# Trop grand !
# Comp#2's turn
# Comp#2 plays value 3.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 127.
# Trop petit !
# Comp#2's turn
# Comp#2 plays value 128.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 189.
# Trop grand !
# Comp#2's turn
# Comp#2 plays value 129.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 159.
# Trop petit !
# Comp#2's turn
# Comp#2 plays value 160.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 174.
# Trop grand !
# Comp#2's turn
# Comp#2 plays value 161.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 167.
# Trop petit !
# Comp#2's turn
# Comp#2 plays value 168.
# Trop petit !
# Comp#3's turn
# Comp#3 plays value 171.
# Trop grand !
# Comp#2's turn
# Comp#2 plays value 169.
# Bravo Comp#2, c'est gagné !
# Comp#4 plays value 1.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 500.
# Trop petit !
# Comp#4's turn
# Comp#4 plays value 501.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 750.
# Trop grand !
# Comp#4's turn
# Comp#4 plays value 502.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 626.
# Trop petit !
# Comp#4's turn
# Comp#4 plays value 627.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 688.
# Trop grand !
# Comp#4's turn
# Comp#4 plays value 628.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 658.
# Trop petit !
# Comp#4's turn
# Comp#4 plays value 659.
# Trop petit !
# Comp#5's turn
# Comp#5 plays value 673.
# Bravo Comp#5, c'est gagné !
# Comp#6 plays value 1.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 500.
# Trop petit !
# Comp#6's turn
# Comp#6 plays value 501.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 750.
# Trop petit !
# Comp#6's turn
# Comp#6 plays value 751.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 875.
# Trop petit !
# Comp#6's turn
# Comp#6 plays value 876.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 938.
# Trop grand !
# Comp#6's turn
# Comp#6 plays value 877.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 907.
# Trop grand !
# Comp#6's turn
# Comp#6 plays value 878.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 892.
# Trop grand !
# Comp#6's turn
# Comp#6 plays value 879.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 885.
# Trop petit !
# Comp#6's turn
# Comp#6 plays value 886.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 889.
# Trop petit !
# Comp#6's turn
# Comp#6 plays value 890.
# Trop petit !
# Comp#7's turn
# Comp#7 plays value 891.
# Bravo Comp#7, c'est gagné !
# Comp#8 plays value 1.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 500.
# Trop grand !
# Comp#8's turn
# Comp#8 plays value 2.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 251.
# Trop grand !
# Comp#8's turn
# Comp#8 plays value 3.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 127.
# Trop grand !
# Comp#8's turn
# Comp#8 plays value 4.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 65.
# Trop grand !
# Comp#8's turn
# Comp#8 plays value 5.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 35.
# Trop petit !
# Comp#8's turn
# Comp#8 plays value 36.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 50.
# Trop grand !
# Comp#8's turn
# Comp#8 plays value 37.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 43.
# Trop petit !
# Comp#8's turn
# Comp#8 plays value 44.
# Trop petit !
# Comp#9's turn
# Comp#9 plays value 47.
# Trop petit !
# Comp#8's turn
# Comp#8 plays value 48.
# Bravo Comp#8, c'est gagné !
# Comp#10 plays value 1.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 500.
# Trop petit !
# Comp#10's turn
# Comp#10 plays value 501.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 750.
# Trop petit !
# Comp#10's turn
# Comp#10 plays value 751.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 875.
# Trop grand !
# Comp#10's turn
# Comp#10 plays value 752.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 813.
# Trop petit !
# Comp#10's turn
# Comp#10 plays value 814.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 844.
# Trop petit !
# Comp#10's turn
# Comp#10 plays value 845.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 860.
# Trop grand !
# Comp#10's turn
# Comp#10 plays value 846.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 853.
# Trop grand !
# Comp#10's turn
# Comp#10 plays value 847.
# Trop petit !
# Comp#11's turn
# Comp#11 plays value 850.
# Trop grand !
# Comp#10's turn
# Comp#10 plays value 848.
# Bravo Comp#10, c'est gagné !
# Comp#12 plays value 1.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 500.
# Trop petit !
# Comp#12's turn
# Comp#12 plays value 501.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 750.
# Trop grand !
# Comp#12's turn
# Comp#12 plays value 502.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 626.
# Trop grand !
# Comp#12's turn
# Comp#12 plays value 503.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 564.
# Trop grand !
# Comp#12's turn
# Comp#12 plays value 504.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 534.
# Trop petit !
# Comp#12's turn
# Comp#12 plays value 535.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 549.
# Trop petit !
# Comp#12's turn
# Comp#12 plays value 550.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 557.
# Trop grand !
# Comp#12's turn
# Comp#12 plays value 551.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 554.
# Trop petit !
# Comp#12's turn
# Comp#12 plays value 555.
# Trop petit !
# Comp#13's turn
# Comp#13 plays value 556.
# Bravo Comp#13, c'est gagné !
# Comp#14 plays value 1.
# Trop petit !
# Comp#15's turn
# Comp#15 plays value 500.
# Trop petit !
# Comp#14's turn
# Comp#14 plays value 501.
# Trop petit !
# Comp#15's turn
# Comp#15 plays value 750.
# Trop grand !
# Comp#14's turn
# Comp#14 plays value 502.
# Trop petit !
# Comp#15's turn
# Comp#15 plays value 626.
# Trop grand !
# Comp#14's turn
# Comp#14 plays value 503.
# Trop petit !
# Comp#15's turn
# Comp#15 plays value 564.
# Trop petit !
# Comp#14's turn
# Comp#14 plays value 565.
# Trop petit !
# Comp#15's turn
# Comp#15 plays value 595.
# Trop grand !
# Comp#14's turn
# Comp#14 plays value 566.
# Bravo Comp#14, c'est gagné !
# Comp#16 plays value 1.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 500.
# Trop petit !
# Comp#16's turn
# Comp#16 plays value 501.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 750.
# Trop petit !
# Comp#16's turn
# Comp#16 plays value 751.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 875.
# Trop grand !
# Comp#16's turn
# Comp#16 plays value 752.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 813.
# Trop petit !
# Comp#16's turn
# Comp#16 plays value 814.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 844.
# Trop petit !
# Comp#16's turn
# Comp#16 plays value 845.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 860.
# Trop grand !
# Comp#16's turn
# Comp#16 plays value 846.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 853.
# Trop grand !
# Comp#16's turn
# Comp#16 plays value 847.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 850.
# Trop grand !
# Comp#16's turn
# Comp#16 plays value 848.
# Trop petit !
# Comp#17's turn
# Comp#17 plays value 849.
# Bravo Comp#17, c'est gagné !
# Comp#18 plays value 1.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 500.
# Trop grand !
# Comp#18's turn
# Comp#18 plays value 2.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 251.
# Trop petit !
# Comp#18's turn
# Comp#18 plays value 252.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 376.
# Trop grand !
# Comp#18's turn
# Comp#18 plays value 253.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 314.
# Trop petit !
# Comp#18's turn
# Comp#18 plays value 315.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 345.
# Trop grand !
# Comp#18's turn
# Comp#18 plays value 316.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 330.
# Trop petit !
# Comp#18's turn
# Comp#18 plays value 331.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 338.
# Trop grand !
# Comp#18's turn
# Comp#18 plays value 332.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 335.
# Trop grand !
# Comp#18's turn
# Comp#18 plays value 333.
# Trop petit !
# Comp#19's turn
# Comp#19 plays value 334.
# Bravo Comp#19, c'est gagné !
# Comp#20 plays value 1.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 500.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 2.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 251.
# Trop petit !
# Comp#20's turn
# Comp#20 plays value 252.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 376.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 253.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 314.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 254.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 284.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 255.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 269.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 256.
# Trop petit !
# Comp#21's turn
# Comp#21 plays value 262.
# Trop grand !
# Comp#20's turn
# Comp#20 plays value 257.
# Bravo Comp#20, c'est gagné !
# Comp#22 plays value 1.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 500.
# Trop grand !
# Comp#22's turn
# Comp#22 plays value 2.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 251.
# Trop petit !
# Comp#22's turn
# Comp#22 plays value 252.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 376.
# Trop petit !
# Comp#22's turn
# Comp#22 plays value 377.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 438.
# Trop grand !
# Comp#22's turn
# Comp#22 plays value 378.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 408.
# Trop grand !
# Comp#22's turn
# Comp#22 plays value 379.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 393.
# Trop petit !
# Comp#22's turn
# Comp#22 plays value 394.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 401.
# Trop petit !
# Comp#22's turn
# Comp#22 plays value 402.
# Trop petit !
# Comp#23's turn
# Comp#23 plays value 405.
# Bravo Comp#23, c'est gagné !
# Comp#24 plays value 1.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 500.
# Trop petit !
# Comp#24's turn
# Comp#24 plays value 501.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 750.
# Trop petit !
# Comp#24's turn
# Comp#24 plays value 751.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 875.
# Trop petit !
# Comp#24's turn
# Comp#24 plays value 876.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 938.
# Trop petit !
# Comp#24's turn
# Comp#24 plays value 939.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 969.
# Trop grand !
# Comp#24's turn
# Comp#24 plays value 940.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 954.
# Trop grand !
# Comp#24's turn
# Comp#24 plays value 941.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 947.
# Trop grand !
# Comp#24's turn
# Comp#24 plays value 942.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 944.
# Trop petit !
# Comp#24's turn
# Comp#24 plays value 945.
# Trop petit !
# Comp#25's turn
# Comp#25 plays value 946.
# Bravo Comp#25, c'est gagné !
# Comp#26 plays value 1.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 500.
# Trop grand !
# Comp#26's turn
# Comp#26 plays value 2.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 251.
# Trop grand !
# Comp#26's turn
# Comp#26 plays value 3.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 127.
# Trop petit !
# Comp#26's turn
# Comp#26 plays value 128.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 189.
# Trop grand !
# Comp#26's turn
# Comp#26 plays value 129.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 159.
# Trop grand !
# Comp#26's turn
# Comp#26 plays value 130.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 144.
# Trop petit !
# Comp#26's turn
# Comp#26 plays value 145.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 152.
# Trop petit !
# Comp#26's turn
# Comp#26 plays value 153.
# Trop petit !
# Comp#27's turn
# Comp#27 plays value 156.
# Trop grand !
# Comp#26's turn
# Comp#26 plays value 154.
# Bravo Comp#26, c'est gagné !
# Comp#28 plays value 1.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 500.
# Trop petit !
# Comp#28's turn
# Comp#28 plays value 501.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 750.
# Trop petit !
# Comp#28's turn
# Comp#28 plays value 751.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 875.
# Trop grand !
# Comp#28's turn
# Comp#28 plays value 752.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 813.
# Trop petit !
# Comp#28's turn
# Comp#28 plays value 814.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 844.
# Trop petit !
# Comp#28's turn
# Comp#28 plays value 845.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 860.
# Trop grand !
# Comp#28's turn
# Comp#28 plays value 846.
# Trop petit !
# Comp#29's turn
# Comp#29 plays value 853.
# Trop grand !
# Comp#28's turn
# Comp#28 plays value 847.
# Bravo Comp#28, c'est gagné !
# Comp#30 plays value 1.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 500.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 501.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 750.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 751.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 875.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 876.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 938.
# Trop grand !
# Comp#30's turn
# Comp#30 plays value 877.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 907.
# Trop grand !
# Comp#30's turn
# Comp#30 plays value 878.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 892.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 893.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 900.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 901.
# Trop petit !
# Comp#31's turn
# Comp#31 plays value 904.
# Trop petit !
# Comp#30's turn
# Comp#30 plays value 905.
# Bravo Comp#30, c'est gagné !
# Comp#32 plays value 1.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 500.
# Trop grand !
# Comp#32's turn
# Comp#32 plays value 2.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 251.
# Trop grand !
# Comp#32's turn
# Comp#32 plays value 3.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 127.
# Trop grand !
# Comp#32's turn
# Comp#32 plays value 4.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 65.
# Trop petit !
# Comp#32's turn
# Comp#32 plays value 66.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 96.
# Trop petit !
# Comp#32's turn
# Comp#32 plays value 97.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 112.
# Trop grand !
# Comp#32's turn
# Comp#32 plays value 98.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 105.
# Trop petit !
# Comp#32's turn
# Comp#32 plays value 106.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 109.
# Trop petit !
# Comp#32's turn
# Comp#32 plays value 110.
# Trop petit !
# Comp#33's turn
# Comp#33 plays value 111.
# Bravo Comp#33, c'est gagné !
# Comp#34 plays value 1.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 500.
# Trop petit !
# Comp#34's turn
# Comp#34 plays value 501.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 750.
# Trop grand !
# Comp#34's turn
# Comp#34 plays value 502.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 626.
# Trop grand !
# Comp#34's turn
# Comp#34 plays value 503.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 564.
# Trop grand !
# Comp#34's turn
# Comp#34 plays value 504.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 534.
# Trop grand !
# Comp#34's turn
# Comp#34 plays value 505.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 519.
# Trop grand !
# Comp#34's turn
# Comp#34 plays value 506.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 512.
# Trop petit !
# Comp#34's turn
# Comp#34 plays value 513.
# Trop petit !
# Comp#35's turn
# Comp#35 plays value 516.
# Bravo Comp#35, c'est gagné !
# Comp#36 plays value 1.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 500.
# Trop petit !
# Comp#36's turn
# Comp#36 plays value 501.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 750.
# Trop grand !
# Comp#36's turn
# Comp#36 plays value 502.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 626.
# Trop grand !
# Comp#36's turn
# Comp#36 plays value 503.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 564.
# Trop grand !
# Comp#36's turn
# Comp#36 plays value 504.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 534.
# Trop grand !
# Comp#36's turn
# Comp#36 plays value 505.
# Trop petit !
# Comp#37's turn
# Comp#37 plays value 519.
# Bravo Comp#37, c'est gagné !
# Comp#38 plays value 1.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 500.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 2.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 251.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 3.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 127.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 4.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 65.
# Trop petit !
# Comp#38's turn
# Comp#38 plays value 66.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 96.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 67.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 81.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 68.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 74.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 69.
# Trop petit !
# Comp#39's turn
# Comp#39 plays value 71.
# Trop grand !
# Comp#38's turn
# Comp#38 plays value 70.
# Bravo Comp#38, c'est gagné !
# Comp#40 plays value 1.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 500.
# Trop grand !
# Comp#40's turn
# Comp#40 plays value 2.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 251.
# Trop grand !
# Comp#40's turn
# Comp#40 plays value 3.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 127.
# Trop grand !
# Comp#40's turn
# Comp#40 plays value 4.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 65.
# Trop petit !
# Comp#40's turn
# Comp#40 plays value 66.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 96.
# Trop grand !
# Comp#40's turn
# Comp#40 plays value 67.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 81.
# Trop petit !
# Comp#40's turn
# Comp#40 plays value 82.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 89.
# Trop petit !
# Comp#40's turn
# Comp#40 plays value 90.
# Trop petit !
# Comp#41's turn
# Comp#41 plays value 93.
# Trop petit !
# Comp#40's turn
# Comp#40 plays value 94.
# Bravo Comp#40, c'est gagné !
# Comp#42 plays value 1.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 500.
# Trop grand !
# Comp#42's turn
# Comp#42 plays value 2.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 251.
# Trop petit !
# Comp#42's turn
# Comp#42 plays value 252.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 376.
# Trop grand !
# Comp#42's turn
# Comp#42 plays value 253.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 314.
# Trop grand !
# Comp#42's turn
# Comp#42 plays value 254.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 284.
# Trop grand !
# Comp#42's turn
# Comp#42 plays value 255.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 269.
# Trop grand !
# Comp#42's turn
# Comp#42 plays value 256.
# Trop petit !
# Comp#43's turn
# Comp#43 plays value 262.
# Trop petit !
# Comp#42's turn
# Comp#42 plays value 263.
# Bravo Comp#42, c'est gagné !
# Comp#44 plays value 1.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 500.
# Trop grand !
# Comp#44's turn
# Comp#44 plays value 2.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 251.
# Trop petit !
# Comp#44's turn
# Comp#44 plays value 252.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 376.
# Trop petit !
# Comp#44's turn
# Comp#44 plays value 377.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 438.
# Trop grand !
# Comp#44's turn
# Comp#44 plays value 378.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 408.
# Trop petit !
# Comp#44's turn
# Comp#44 plays value 409.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 423.
# Trop grand !
# Comp#44's turn
# Comp#44 plays value 410.
# Trop petit !
# Comp#45's turn
# Comp#45 plays value 416.
# Trop grand !
# Comp#44's turn
# Comp#44 plays value 411.
# Bravo Comp#44, c'est gagné !
# Comp#46 plays value 1.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 500.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 501.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 750.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 751.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 875.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 876.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 938.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 939.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 969.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 970.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 985.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 986.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 993.
# Trop petit !
# Comp#46's turn
# Comp#46 plays value 994.
# Trop petit !
# Comp#47's turn
# Comp#47 plays value 997.
# Trop grand !
# Comp#46's turn
# Comp#46 plays value 995.
# Bravo Comp#46, c'est gagné !
# Comp#48 plays value 1.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 500.
# Trop petit !
# Comp#48's turn
# Comp#48 plays value 501.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 750.
# Trop petit !
# Comp#48's turn
# Comp#48 plays value 751.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 875.
# Trop grand !
# Comp#48's turn
# Comp#48 plays value 752.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 813.
# Trop grand !
# Comp#48's turn
# Comp#48 plays value 753.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 783.
# Trop petit !
# Comp#48's turn
# Comp#48 plays value 784.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 798.
# Trop grand !
# Comp#48's turn
# Comp#48 plays value 785.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 791.
# Trop petit !
# Comp#48's turn
# Comp#48 plays value 792.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 795.
# Trop grand !
# Comp#48's turn
# Comp#48 plays value 793.
# Trop petit !
# Comp#49's turn
# Comp#49 plays value 794.
# Bravo Comp#49, c'est gagné !
# Comp#50 plays value 1.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 500.
# Trop grand !
# Comp#50's turn
# Comp#50 plays value 2.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 251.
# Trop petit !
# Comp#50's turn
# Comp#50 plays value 252.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 376.
# Trop grand !
# Comp#50's turn
# Comp#50 plays value 253.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 314.
# Trop grand !
# Comp#50's turn
# Comp#50 plays value 254.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 284.
# Trop petit !
# Comp#50's turn
# Comp#50 plays value 285.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 299.
# Trop grand !
# Comp#50's turn
# Comp#50 plays value 286.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 292.
# Trop petit !
# Comp#50's turn
# Comp#50 plays value 293.
# Trop petit !
# Comp#51's turn
# Comp#51 plays value 296.
# Bravo Comp#51, c'est gagné !
# Comp#52 plays value 1.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 500.
# Trop petit !
# Comp#52's turn
# Comp#52 plays value 501.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 750.
# Trop grand !
# Comp#52's turn
# Comp#52 plays value 502.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 626.
# Trop petit !
# Comp#52's turn
# Comp#52 plays value 627.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 688.
# Trop petit !
# Comp#52's turn
# Comp#52 plays value 689.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 719.
# Trop grand !
# Comp#52's turn
# Comp#52 plays value 690.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 704.
# Trop grand !
# Comp#52's turn
# Comp#52 plays value 691.
# Trop petit !
# Comp#53's turn
# Comp#53 plays value 697.
# Trop grand !
# Comp#52's turn
# Comp#52 plays value 692.
# Bravo Comp#52, c'est gagné !
# Comp#54 plays value 1.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 500.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 501.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 750.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 751.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 875.
# Trop grand !
# Comp#54's turn
# Comp#54 plays value 752.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 813.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 814.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 844.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 845.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 860.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 861.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 868.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 869.
# Trop petit !
# Comp#55's turn
# Comp#55 plays value 872.
# Trop petit !
# Comp#54's turn
# Comp#54 plays value 873.
# Bravo Comp#54, c'est gagné !
# Comp#56 plays value 1.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 500.
# Trop grand !
# Comp#56's turn
# Comp#56 plays value 2.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 251.
# Trop petit !
# Comp#56's turn
# Comp#56 plays value 252.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 376.
# Trop petit !
# Comp#56's turn
# Comp#56 plays value 377.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 438.
# Trop petit !
# Comp#56's turn
# Comp#56 plays value 439.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 469.
# Trop grand !
# Comp#56's turn
# Comp#56 plays value 440.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 454.
# Trop grand !
# Comp#56's turn
# Comp#56 plays value 441.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 447.
# Trop petit !
# Comp#56's turn
# Comp#56 plays value 448.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 451.
# Trop grand !
# Comp#56's turn
# Comp#56 plays value 449.
# Trop petit !
# Comp#57's turn
# Comp#57 plays value 450.
# Bravo Comp#57, c'est gagné !
# Comp#58 plays value 1.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 500.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 2.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 251.
# Trop petit !
# Comp#58's turn
# Comp#58 plays value 252.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 376.
# Trop petit !
# Comp#58's turn
# Comp#58 plays value 377.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 438.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 378.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 408.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 379.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 393.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 380.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 386.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 381.
# Trop petit !
# Comp#59's turn
# Comp#59 plays value 383.
# Trop grand !
# Comp#58's turn
# Comp#58 plays value 382.
# Bravo Comp#58, c'est gagné !
# Comp#60 plays value 1.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 500.
# Trop petit !
# Comp#60's turn
# Comp#60 plays value 501.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 750.
# Trop grand !
# Comp#60's turn
# Comp#60 plays value 502.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 626.
# Trop grand !
# Comp#60's turn
# Comp#60 plays value 503.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 564.
# Trop petit !
# Comp#60's turn
# Comp#60 plays value 565.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 595.
# Trop grand !
# Comp#60's turn
# Comp#60 plays value 566.
# Trop petit !
# Comp#61's turn
# Comp#61 plays value 580.
# Trop petit !
# Comp#60's turn
# Comp#60 plays value 581.
# Bravo Comp#60, c'est gagné !
# Comp#62 plays value 1.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 500.
# Trop grand !
# Comp#62's turn
# Comp#62 plays value 2.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 251.
# Trop petit !
# Comp#62's turn
# Comp#62 plays value 252.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 376.
# Trop grand !
# Comp#62's turn
# Comp#62 plays value 253.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 314.
# Trop grand !
# Comp#62's turn
# Comp#62 plays value 254.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 284.
# Trop petit !
# Comp#62's turn
# Comp#62 plays value 285.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 299.
# Trop petit !
# Comp#62's turn
# Comp#62 plays value 300.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 307.
# Trop grand !
# Comp#62's turn
# Comp#62 plays value 301.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 304.
# Trop petit !
# Comp#62's turn
# Comp#62 plays value 305.
# Trop petit !
# Comp#63's turn
# Comp#63 plays value 306.
# Bravo Comp#63, c'est gagné !
# Comp#64 plays value 1.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 500.
# Trop grand !
# Comp#64's turn
# Comp#64 plays value 2.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 251.
# Trop grand !
# Comp#64's turn
# Comp#64 plays value 3.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 127.
# Trop petit !
# Comp#64's turn
# Comp#64 plays value 128.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 189.
# Trop grand !
# Comp#64's turn
# Comp#64 plays value 129.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 159.
# Trop petit !
# Comp#64's turn
# Comp#64 plays value 160.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 174.
# Trop grand !
# Comp#64's turn
# Comp#64 plays value 161.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 167.
# Trop grand !
# Comp#64's turn
# Comp#64 plays value 162.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 164.
# Trop petit !
# Comp#64's turn
# Comp#64 plays value 165.
# Trop petit !
# Comp#65's turn
# Comp#65 plays value 166.
# Bravo Comp#65, c'est gagné !
# Comp#66 plays value 1.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 500.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 2.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 251.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 3.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 127.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 4.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 65.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 5.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 35.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 6.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 20.
# Trop petit !
# Comp#66's turn
# Comp#66 plays value 21.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 28.
# Trop grand !
# Comp#66's turn
# Comp#66 plays value 22.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 25.
# Trop petit !
# Comp#66's turn
# Comp#66 plays value 26.
# Trop petit !
# Comp#67's turn
# Comp#67 plays value 27.
# Bravo Comp#67, c'est gagné !
# Comp#68 plays value 1.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 500.
# Trop grand !
# Comp#68's turn
# Comp#68 plays value 2.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 251.
# Trop grand !
# Comp#68's turn
# Comp#68 plays value 3.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 127.
# Trop grand !
# Comp#68's turn
# Comp#68 plays value 4.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 65.
# Trop petit !
# Comp#68's turn
# Comp#68 plays value 66.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 96.
# Trop petit !
# Comp#68's turn
# Comp#68 plays value 97.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 112.
# Trop petit !
# Comp#68's turn
# Comp#68 plays value 113.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 120.
# Trop petit !
# Comp#68's turn
# Comp#68 plays value 121.
# Trop petit !
# Comp#69's turn
# Comp#69 plays value 124.
# Trop grand !
# Comp#68's turn
# Comp#68 plays value 122.
# Bravo Comp#68, c'est gagné !
# Comp#70 plays value 1.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 500.
# Trop grand !
# Comp#70's turn
# Comp#70 plays value 2.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 251.
# Trop petit !
# Comp#70's turn
# Comp#70 plays value 252.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 376.
# Trop petit !
# Comp#70's turn
# Comp#70 plays value 377.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 438.
# Trop petit !
# Comp#70's turn
# Comp#70 plays value 439.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 469.
# Trop petit !
# Comp#70's turn
# Comp#70 plays value 470.
# Trop petit !
# Comp#71's turn
# Comp#71 plays value 485.
# Trop grand !
# Comp#70's turn
# Comp#70 plays value 471.
# Bravo Comp#70, c'est gagné !
# Comp#72 plays value 1.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 500.
# Trop petit !
# Comp#72's turn
# Comp#72 plays value 501.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 750.
# Trop grand !
# Comp#72's turn
# Comp#72 plays value 502.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 626.
# Trop petit !
# Comp#72's turn
# Comp#72 plays value 627.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 688.
# Trop grand !
# Comp#72's turn
# Comp#72 plays value 628.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 658.
# Trop grand !
# Comp#72's turn
# Comp#72 plays value 629.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 643.
# Trop grand !
# Comp#72's turn
# Comp#72 plays value 630.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 636.
# Trop petit !
# Comp#72's turn
# Comp#72 plays value 637.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 640.
# Trop grand !
# Comp#72's turn
# Comp#72 plays value 638.
# Trop petit !
# Comp#73's turn
# Comp#73 plays value 639.
# Bravo Comp#73, c'est gagné !
# Comp#74 plays value 1.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 500.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 2.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 251.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 3.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 127.
# Trop petit !
# Comp#74's turn
# Comp#74 plays value 128.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 189.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 129.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 159.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 130.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 144.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 131.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 137.
# Trop grand !
# Comp#74's turn
# Comp#74 plays value 132.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 134.
# Trop petit !
# Comp#74's turn
# Comp#74 plays value 135.
# Trop petit !
# Comp#75's turn
# Comp#75 plays value 136.
# Bravo Comp#75, c'est gagné !
# Comp#76 plays value 1.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 500.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 501.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 750.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 751.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 875.
# Trop grand !
# Comp#76's turn
# Comp#76 plays value 752.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 813.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 814.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 844.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 845.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 860.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 861.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 868.
# Trop petit !
# Comp#76's turn
# Comp#76 plays value 869.
# Trop petit !
# Comp#77's turn
# Comp#77 plays value 872.
# Bravo Comp#77, c'est gagné !
# Comp#78 plays value 1.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 500.
# Trop petit !
# Comp#78's turn
# Comp#78 plays value 501.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 750.
# Trop petit !
# Comp#78's turn
# Comp#78 plays value 751.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 875.
# Trop grand !
# Comp#78's turn
# Comp#78 plays value 752.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 813.
# Trop grand !
# Comp#78's turn
# Comp#78 plays value 753.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 783.
# Trop petit !
# Comp#78's turn
# Comp#78 plays value 784.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 798.
# Trop petit !
# Comp#78's turn
# Comp#78 plays value 799.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 806.
# Trop grand !
# Comp#78's turn
# Comp#78 plays value 800.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 803.
# Trop petit !
# Comp#78's turn
# Comp#78 plays value 804.
# Trop petit !
# Comp#79's turn
# Comp#79 plays value 805.
# Bravo Comp#79, c'est gagné !
# Comp#80 plays value 1.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 500.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 501.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 750.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 751.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 875.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 876.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 938.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 939.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 969.
# Trop grand !
# Comp#80's turn
# Comp#80 plays value 940.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 954.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 955.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 962.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 963.
# Trop petit !
# Comp#81's turn
# Comp#81 plays value 966.
# Trop petit !
# Comp#80's turn
# Comp#80 plays value 967.
# Bravo Comp#80, c'est gagné !
# Comp#82 plays value 1.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 500.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 2.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 251.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 3.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 127.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 4.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 65.
# Trop petit !
# Comp#82's turn
# Comp#82 plays value 66.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 96.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 67.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 81.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 68.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 74.
# Trop grand !
# Comp#82's turn
# Comp#82 plays value 69.
# Trop petit !
# Comp#83's turn
# Comp#83 plays value 71.
# Trop petit !
# Comp#82's turn
# Comp#82 plays value 72.
# Bravo Comp#82, c'est gagné !
# Comp#84 plays value 1.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 500.
# Trop grand !
# Comp#84's turn
# Comp#84 plays value 2.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 251.
# Trop petit !
# Comp#84's turn
# Comp#84 plays value 252.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 376.
# Trop grand !
# Comp#84's turn
# Comp#84 plays value 253.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 314.
# Trop grand !
# Comp#84's turn
# Comp#84 plays value 254.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 284.
# Trop petit !
# Comp#84's turn
# Comp#84 plays value 285.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 299.
# Trop petit !
# Comp#84's turn
# Comp#84 plays value 300.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 307.
# Trop petit !
# Comp#84's turn
# Comp#84 plays value 308.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 311.
# Trop petit !
# Comp#84's turn
# Comp#84 plays value 312.
# Trop petit !
# Comp#85's turn
# Comp#85 plays value 313.
# Bravo Comp#85, c'est gagné !
# Comp#86 plays value 1.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 500.
# Trop petit !
# Comp#86's turn
# Comp#86 plays value 501.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 750.
# Trop grand !
# Comp#86's turn
# Comp#86 plays value 502.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 626.
# Trop petit !
# Comp#86's turn
# Comp#86 plays value 627.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 688.
# Trop grand !
# Comp#86's turn
# Comp#86 plays value 628.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 658.
# Trop petit !
# Comp#86's turn
# Comp#86 plays value 659.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 673.
# Trop grand !
# Comp#86's turn
# Comp#86 plays value 660.
# Trop petit !
# Comp#87's turn
# Comp#87 plays value 666.
# Trop petit !
# Comp#86's turn
# Comp#86 plays value 667.
# Bravo Comp#86, c'est gagné !
# Comp#88 plays value 1.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 500.
# Trop petit !
# Comp#88's turn
# Comp#88 plays value 501.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 750.
# Trop petit !
# Comp#88's turn
# Comp#88 plays value 751.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 875.
# Trop grand !
# Comp#88's turn
# Comp#88 plays value 752.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 813.
# Trop grand !
# Comp#88's turn
# Comp#88 plays value 753.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 783.
# Trop petit !
# Comp#88's turn
# Comp#88 plays value 784.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 798.
# Trop petit !
# Comp#88's turn
# Comp#88 plays value 799.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 806.
# Trop grand !
# Comp#88's turn
# Comp#88 plays value 800.
# Trop petit !
# Comp#89's turn
# Comp#89 plays value 803.
# Trop grand !
# Comp#88's turn
# Comp#88 plays value 801.
# Bravo Comp#88, c'est gagné !
# Comp#90 plays value 1.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 500.
# Trop grand !
# Comp#90's turn
# Comp#90 plays value 2.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 251.
# Trop grand !
# Comp#90's turn
# Comp#90 plays value 3.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 127.
# Trop petit !
# Comp#90's turn
# Comp#90 plays value 128.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 189.
# Trop grand !
# Comp#90's turn
# Comp#90 plays value 129.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 159.
# Trop grand !
# Comp#90's turn
# Comp#90 plays value 130.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 144.
# Trop grand !
# Comp#90's turn
# Comp#90 plays value 131.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 137.
# Trop petit !
# Comp#90's turn
# Comp#90 plays value 138.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 141.
# Trop petit !
# Comp#90's turn
# Comp#90 plays value 142.
# Trop petit !
# Comp#91's turn
# Comp#91 plays value 143.
# Bravo Comp#91, c'est gagné !
# Comp#92 plays value 1.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 500.
# Trop grand !
# Comp#92's turn
# Comp#92 plays value 2.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 251.
# Trop grand !
# Comp#92's turn
# Comp#92 plays value 3.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 127.
# Trop grand !
# Comp#92's turn
# Comp#92 plays value 4.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 65.
# Trop grand !
# Comp#92's turn
# Comp#92 plays value 5.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 35.
# Trop petit !
# Comp#92's turn
# Comp#92 plays value 36.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 50.
# Trop petit !
# Comp#92's turn
# Comp#92 plays value 51.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 58.
# Trop petit !
# Comp#92's turn
# Comp#92 plays value 59.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 62.
# Trop petit !
# Comp#92's turn
# Comp#92 plays value 63.
# Trop petit !
# Comp#93's turn
# Comp#93 plays value 64.
# Bravo Comp#93, c'est gagné !
# Comp#94 plays value 1.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 500.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 501.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 750.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 751.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 875.
# Trop grand !
# Comp#94's turn
# Comp#94 plays value 752.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 813.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 814.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 844.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 845.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 860.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 861.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 868.
# Trop grand !
# Comp#94's turn
# Comp#94 plays value 862.
# Trop petit !
# Comp#95's turn
# Comp#95 plays value 865.
# Trop petit !
# Comp#94's turn
# Comp#94 plays value 866.
# Bravo Comp#94, c'est gagné !
# Comp#96 plays value 1.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 500.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 501.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 750.
# Trop grand !
# Comp#96's turn
# Comp#96 plays value 502.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 626.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 627.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 688.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 689.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 719.
# Trop grand !
# Comp#96's turn
# Comp#96 plays value 690.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 704.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 705.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 712.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 713.
# Trop petit !
# Comp#97's turn
# Comp#97 plays value 716.
# Trop petit !
# Comp#96's turn
# Comp#96 plays value 717.
# Bravo Comp#96, c'est gagné !
# Comp#98 plays value 1.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 500.
# Trop grand !
# Comp#98's turn
# Comp#98 plays value 2.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 251.
# Trop grand !
# Comp#98's turn
# Comp#98 plays value 3.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 127.
# Trop grand !
# Comp#98's turn
# Comp#98 plays value 4.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 65.
# Trop petit !
# Comp#98's turn
# Comp#98 plays value 66.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 96.
# Trop petit !
# Comp#98's turn
# Comp#98 plays value 97.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 112.
# Trop grand !
# Comp#98's turn
# Comp#98 plays value 98.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 105.
# Trop grand !
# Comp#98's turn
# Comp#98 plays value 99.
# Trop petit !
# Comp#99's turn
# Comp#99 plays value 102.
# Bravo Comp#99, c'est gagné !
# Comp#100 plays value 1.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 500.
# Trop petit !
# Comp#100's turn
# Comp#100 plays value 501.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 750.
# Trop petit !
# Comp#100's turn
# Comp#100 plays value 751.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 875.
# Trop grand !
# Comp#100's turn
# Comp#100 plays value 752.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 813.
# Trop petit !
# Comp#100's turn
# Comp#100 plays value 814.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 844.
# Trop grand !
# Comp#100's turn
# Comp#100 plays value 815.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 829.
# Trop petit !
# Comp#100's turn
# Comp#100 plays value 830.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 837.
# Trop grand !
# Comp#100's turn
# Comp#100 plays value 831.
# Trop petit !
# Comp#101's turn
# Comp#101 plays value 834.
# Bravo Comp#101, c'est gagné !
# Comp#102 plays value 1.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 500.
# Trop petit !
# Comp#102's turn
# Comp#102 plays value 501.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 750.
# Trop grand !
# Comp#102's turn
# Comp#102 plays value 502.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 626.
# Trop petit !
# Comp#102's turn
# Comp#102 plays value 627.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 688.
# Trop grand !
# Comp#102's turn
# Comp#102 plays value 628.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 658.
# Trop grand !
# Comp#102's turn
# Comp#102 plays value 629.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 643.
# Trop petit !
# Comp#102's turn
# Comp#102 plays value 644.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 651.
# Trop grand !
# Comp#102's turn
# Comp#102 plays value 645.
# Trop petit !
# Comp#103's turn
# Comp#103 plays value 648.
# Bravo Comp#103, c'est gagné !
# Comp#104 plays value 1.
# Trop petit !
# Comp#105's turn
# Comp#105 plays value 500.
# Trop grand !
# Comp#104's turn
# Comp#104 plays value 2.
# Trop petit !
# Comp#105's turn
# Comp#105 plays value 251.
# Trop grand !
# Comp#104's turn
# Comp#104 plays value 3.
# Trop petit !
# Comp#105's turn
# Comp#105 plays value 127.
# Trop petit !
# Comp#104's turn
# Comp#104 plays value 128.
# Trop petit !
# Comp#105's turn
# Comp#105 plays value 189.
# Trop petit !
# Comp#104's turn
# Comp#104 plays value 190.
# Trop petit !
# Comp#105's turn
# Comp#105 plays value 220.
# Trop grand !
# Comp#104's turn
# Comp#104 plays value 191.
# Bravo Comp#104, c'est gagné !
# Comp#106 plays value 1.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 500.
# Trop grand !
# Comp#106's turn
# Comp#106 plays value 2.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 251.
# Trop petit !
# Comp#106's turn
# Comp#106 plays value 252.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 376.
# Trop grand !
# Comp#106's turn
# Comp#106 plays value 253.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 314.
# Trop petit !
# Comp#106's turn
# Comp#106 plays value 315.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 345.
# Trop petit !
# Comp#106's turn
# Comp#106 plays value 346.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 361.
# Trop grand !
# Comp#106's turn
# Comp#106 plays value 347.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 354.
# Trop petit !
# Comp#106's turn
# Comp#106 plays value 355.
# Trop petit !
# Comp#107's turn
# Comp#107 plays value 358.
# Trop petit !
# Comp#106's turn
# Comp#106 plays value 359.
# Bravo Comp#106, c'est gagné !
# Comp#108 plays value 1.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 500.
# Trop petit !
# Comp#108's turn
# Comp#108 plays value 501.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 750.
# Trop grand !
# Comp#108's turn
# Comp#108 plays value 502.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 626.
# Trop petit !
# Comp#108's turn
# Comp#108 plays value 627.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 688.
# Trop petit !
# Comp#108's turn
# Comp#108 plays value 689.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 719.
# Trop grand !
# Comp#108's turn
# Comp#108 plays value 690.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 704.
# Trop grand !
# Comp#108's turn
# Comp#108 plays value 691.
# Trop petit !
# Comp#109's turn
# Comp#109 plays value 697.
# Trop petit !
# Comp#108's turn
# Comp#108 plays value 698.
# Bravo Comp#108, c'est gagné !
# Comp#110 plays value 1.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 500.
# Trop grand !
# Comp#110's turn
# Comp#110 plays value 2.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 251.
# Trop petit !
# Comp#110's turn
# Comp#110 plays value 252.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 376.
# Trop petit !
# Comp#110's turn
# Comp#110 plays value 377.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 438.
# Trop petit !
# Comp#110's turn
# Comp#110 plays value 439.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 469.
# Trop petit !
# Comp#110's turn
# Comp#110 plays value 470.
# Trop petit !
# Comp#111's turn
# Comp#111 plays value 485.
# Trop petit !
# Comp#110's turn
# Comp#110 plays value 486.
# Trop petit !
# Comp#111's turn
# ...
# Comp#162's turn
# Comp#162 plays value 448.
# Trop petit !
# Comp#163's turn
# Comp#163 plays value 451.
# Trop petit !
# Comp#162's turn
# Comp#162 plays value 452.
# Trop petit !
# Comp#163's turn
# Comp#163 plays value 453.
# Bravo Comp#163, c'est gagné !
# Comp#164 plays value 1.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 500.
# Trop grand !
# Comp#164's turn
# Comp#164 plays value 2.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 251.
# Trop grand !
# Comp#164's turn
# Comp#164 plays value 3.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 127.
# Trop petit !
# Comp#164's turn
# Comp#164 plays value 128.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 189.
# Trop petit !
# Comp#164's turn
# Comp#164 plays value 190.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 220.
# Trop petit !
# Comp#164's turn
# Comp#164 plays value 221.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 236.
# Trop grand !
# Comp#164's turn
# Comp#164 plays value 222.
# Trop petit !
# Comp#165's turn
# Comp#165 plays value 229.
# Trop petit !
# Comp#164's turn
# Comp#164 plays value 230.
# Bravo Comp#164, c'est gagné !
# Comp#166 plays value 1.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 500.
# Trop grand !
# Comp#166's turn
# Comp#166 plays value 2.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 251.
# Trop petit !
# Comp#166's turn
# Comp#166 plays value 252.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 376.
# Trop grand !
# Comp#166's turn
# Comp#166 plays value 253.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 314.
# Trop grand !
# Comp#166's turn
# Comp#166 plays value 254.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 284.
# Trop petit !
# Comp#166's turn
# Comp#166 plays value 285.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 299.
# Trop petit !
# Comp#166's turn
# Comp#166 plays value 300.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 307.
# Trop petit !
# Comp#166's turn
# Comp#166 plays value 308.
# Trop petit !
# Comp#167's turn
# Comp#167 plays value 311.
# Trop petit !
# Comp#166's turn
# Comp#166 plays value 312.
# Bravo Comp#166, c'est gagné !
# Comp#168 plays value 1.
# Trop petit !
# Comp#169's turn
# Comp#169 plays value 500.
# Trop grand !
# Comp#168's turn
# Comp#168 plays value 2.
# Trop petit !
# Comp#169's turn
# Comp#169 plays value 251.
# Trop petit !
# Comp#168's turn
# Comp#168 plays value 252.
# Trop petit !
# Comp#169's turn
# Comp#169 plays value 376.
# Trop petit !
# Comp#168's turn
# Comp#168 plays value 377.
# Trop petit !
# Comp#169's turn
# Comp#169 plays value 438.
# Trop grand !
# Comp#168's turn
# Comp#168 plays value 378.
# Trop petit !
# Comp#169's turn
# Comp#169 plays value 408.
# Bravo Comp#169, c'est gagné !
# Comp#170 plays value 1.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 500.
# Trop petit !
# Comp#170's turn
# Comp#170 plays value 501.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 750.
# Trop petit !
# Comp#170's turn
# Comp#170 plays value 751.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 875.
# Trop grand !
# Comp#170's turn
# Comp#170 plays value 752.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 813.
# Trop grand !
# Comp#170's turn
# Comp#170 plays value 753.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 783.
# Trop petit !
# Comp#170's turn
# Comp#170 plays value 784.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 798.
# Trop petit !
# Comp#170's turn
# Comp#170 plays value 799.
# Trop petit !
# Comp#171's turn
# Comp#171 plays value 806.
# Bravo Comp#171, c'est gagné !
# Comp#172 plays value 1.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 500.
# Trop petit !
# Comp#172's turn
# Comp#172 plays value 501.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 750.
# Trop petit !
# Comp#172's turn
# Comp#172 plays value 751.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 875.
# Trop grand !
# Comp#172's turn
# Comp#172 plays value 752.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 813.
# Trop grand !
# Comp#172's turn
# Comp#172 plays value 753.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 783.
# Trop grand !
# Comp#172's turn
# Comp#172 plays value 754.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 768.
# Trop petit !
# Comp#172's turn
# Comp#172 plays value 769.
# Trop petit !
# Comp#173's turn
# Comp#173 plays value 776.
# Trop petit !
# Comp#172's turn
# Comp#172 plays value 777.
# Bravo Comp#172, c'est gagné !
# Comp#174 plays value 1.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 500.
# Trop grand !
# Comp#174's turn
# Comp#174 plays value 2.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 251.
# Trop grand !
# Comp#174's turn
# Comp#174 plays value 3.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 127.
# Trop grand !
# Comp#174's turn
# Comp#174 plays value 4.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 65.
# Trop petit !
# Comp#174's turn
# Comp#174 plays value 66.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 96.
# Trop grand !
# Comp#174's turn
# Comp#174 plays value 67.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 81.
# Trop petit !
# Comp#174's turn
# Comp#174 plays value 82.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 89.
# Trop petit !
# Comp#174's turn
# Comp#174 plays value 90.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 93.
# Trop grand !
# Comp#174's turn
# Comp#174 plays value 91.
# Trop petit !
# Comp#175's turn
# Comp#175 plays value 92.
# Bravo Comp#175, c'est gagné !
# Comp#176 plays value 1.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 500.
# Trop petit !
# Comp#176's turn
# Comp#176 plays value 501.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 750.
# Trop grand !
# Comp#176's turn
# Comp#176 plays value 502.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 626.
# Trop grand !
# Comp#176's turn
# Comp#176 plays value 503.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 564.
# Trop grand !
# Comp#176's turn
# Comp#176 plays value 504.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 534.
# Trop grand !
# Comp#176's turn
# Comp#176 plays value 505.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 519.
# Trop petit !
# Comp#176's turn
# Comp#176 plays value 520.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 527.
# Trop grand !
# Comp#176's turn
# Comp#176 plays value 521.
# Trop petit !
# Comp#177's turn
# Comp#177 plays value 524.
# Trop petit !
# Comp#176's turn
# Comp#176 plays value 525.
# Bravo Comp#176, c'est gagné !
# Comp#178 plays value 1.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 500.
# Trop grand !
# Comp#178's turn
# Comp#178 plays value 2.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 251.
# Trop petit !
# Comp#178's turn
# Comp#178 plays value 252.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 376.
# Trop grand !
# Comp#178's turn
# Comp#178 plays value 253.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 314.
# Trop petit !
# Comp#178's turn
# Comp#178 plays value 315.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 345.
# Trop grand !
# Comp#178's turn
# Comp#178 plays value 316.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 330.
# Trop petit !
# Comp#178's turn
# Comp#178 plays value 331.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 338.
# Trop petit !
# Comp#178's turn
# Comp#178 plays value 339.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 342.
# Trop petit !
# Comp#178's turn
# Comp#178 plays value 343.
# Trop petit !
# Comp#179's turn
# Comp#179 plays value 344.
# Bravo Comp#179, c'est gagné !
# Comp#180 plays value 1.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 500.
# Trop petit !
# Comp#180's turn
# Comp#180 plays value 501.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 750.
# Trop grand !
# Comp#180's turn
# Comp#180 plays value 502.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 626.
# Trop petit !
# Comp#180's turn
# Comp#180 plays value 627.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 688.
# Trop grand !
# Comp#180's turn
# Comp#180 plays value 628.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 658.
# Trop grand !
# Comp#180's turn
# Comp#180 plays value 629.
# Trop petit !
# Comp#181's turn
# Comp#181 plays value 643.
# Trop petit !
# Comp#180's turn
# Comp#180 plays value 644.
# Bravo Comp#180, c'est gagné !
# Comp#182 plays value 1.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 500.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 2.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 251.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 3.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 127.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 4.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 65.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 5.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 35.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 6.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 20.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 7.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 13.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 8.
# Trop petit !
# Comp#183's turn
# Comp#183 plays value 10.
# Trop grand !
# Comp#182's turn
# Comp#182 plays value 9.
# Bravo Comp#182, c'est gagné !
# Comp#184 plays value 1.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 500.
# Trop petit !
# Comp#184's turn
# Comp#184 plays value 501.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 750.
# Trop grand !
# Comp#184's turn
# Comp#184 plays value 502.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 626.
# Trop grand !
# Comp#184's turn
# Comp#184 plays value 503.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 564.
# Trop petit !
# Comp#184's turn
# Comp#184 plays value 565.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 595.
# Trop grand !
# Comp#184's turn
# Comp#184 plays value 566.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 580.
# Trop grand !
# Comp#184's turn
# Comp#184 plays value 567.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 573.
# Trop petit !
# Comp#184's turn
# Comp#184 plays value 574.
# Trop petit !
# Comp#185's turn
# Comp#185 plays value 577.
# Bravo Comp#185, c'est gagné !
# Comp#186 plays value 1.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 500.
# Trop petit !
# Comp#186's turn
# Comp#186 plays value 501.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 750.
# Trop grand !
# Comp#186's turn
# Comp#186 plays value 502.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 626.
# Trop grand !
# Comp#186's turn
# Comp#186 plays value 503.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 564.
# Trop petit !
# Comp#186's turn
# Comp#186 plays value 565.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 595.
# Trop grand !
# Comp#186's turn
# Comp#186 plays value 566.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 580.
# Trop grand !
# Comp#186's turn
# Comp#186 plays value 567.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 573.
# Trop petit !
# Comp#186's turn
# Comp#186 plays value 574.
# Trop petit !
# Comp#187's turn
# Comp#187 plays value 577.
# Bravo Comp#187, c'est gagné !
# Comp#188 plays value 1.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 500.
# Trop grand !
# Comp#188's turn
# Comp#188 plays value 2.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 251.
# Trop grand !
# Comp#188's turn
# Comp#188 plays value 3.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 127.
# Trop petit !
# Comp#188's turn
# Comp#188 plays value 128.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 189.
# Trop petit !
# Comp#188's turn
# Comp#188 plays value 190.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 220.
# Trop grand !
# Comp#188's turn
# Comp#188 plays value 191.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 205.
# Trop grand !
# Comp#188's turn
# Comp#188 plays value 192.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 198.
# Trop petit !
# Comp#188's turn
# Comp#188 plays value 199.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 202.
# Trop petit !
# Comp#188's turn
# Comp#188 plays value 203.
# Trop petit !
# Comp#189's turn
# Comp#189 plays value 204.
# Bravo Comp#189, c'est gagné !
# Comp#190 plays value 1.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 500.
# Trop grand !
# Comp#190's turn
# Comp#190 plays value 2.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 251.
# Trop grand !
# Comp#190's turn
# Comp#190 plays value 3.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 127.
# Trop grand !
# Comp#190's turn
# Comp#190 plays value 4.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 65.
# Trop grand !
# Comp#190's turn
# Comp#190 plays value 5.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 35.
# Trop petit !
# Comp#190's turn
# Comp#190 plays value 36.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 50.
# Trop petit !
# Comp#190's turn
# Comp#190 plays value 51.
# Trop petit !
# Comp#191's turn
# Comp#191 plays value 58.
# Bravo Comp#191, c'est gagné !
# Comp#192 plays value 1.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 500.
# Trop grand !
# Comp#192's turn
# Comp#192 plays value 2.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 251.
# Trop grand !
# Comp#192's turn
# Comp#192 plays value 3.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 127.
# Trop petit !
# Comp#192's turn
# Comp#192 plays value 128.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 189.
# Trop petit !
# Comp#192's turn
# Comp#192 plays value 190.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 220.
# Trop petit !
# Comp#192's turn
# Comp#192 plays value 221.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 236.
# Trop grand !
# Comp#192's turn
# Comp#192 plays value 222.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 229.
# Trop petit !
# Comp#192's turn
# Comp#192 plays value 230.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 233.
# Trop grand !
# Comp#192's turn
# Comp#192 plays value 231.
# Trop petit !
# Comp#193's turn
# Comp#193 plays value 232.
# Bravo Comp#193, c'est gagné !
# Comp#194 plays value 1.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 500.
# Trop petit !
# Comp#194's turn
# Comp#194 plays value 501.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 750.
# Trop grand !
# Comp#194's turn
# Comp#194 plays value 502.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 626.
# Trop petit !
# Comp#194's turn
# Comp#194 plays value 627.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 688.
# Trop petit !
# Comp#194's turn
# Comp#194 plays value 689.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 719.
# Trop petit !
# Comp#194's turn
# Comp#194 plays value 720.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 735.
# Trop petit !
# Comp#194's turn
# Comp#194 plays value 736.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 743.
# Trop grand !
# Comp#194's turn
# Comp#194 plays value 737.
# Trop petit !
# Comp#195's turn
# Comp#195 plays value 740.
# Bravo Comp#195, c'est gagné !
# Comp#196 plays value 1.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 500.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 2.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 251.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 3.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 127.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 4.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 65.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 5.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 35.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 6.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 20.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 7.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 13.
# Trop petit !
# Comp#196's turn
# Comp#196 plays value 14.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 17.
# Trop grand !
# Comp#196's turn
# Comp#196 plays value 15.
# Trop petit !
# Comp#197's turn
# Comp#197 plays value 16.
# Bravo Comp#197, c'est gagné !
# Comp#198 plays value 1.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 500.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 501.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 750.
# Trop grand !
# Comp#198's turn
# Comp#198 plays value 502.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 626.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 627.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 688.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 689.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 719.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 720.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 735.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 736.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 743.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 744.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 747.
# Trop petit !
# Comp#198's turn
# Comp#198 plays value 748.
# Trop petit !
# Comp#199's turn
# Comp#199 plays value 749.
# Bravo Comp#199, c'est gagné !
# byOne : 0, dicho : 100

# %% [markdown]
# ## 2. Gestion civile
#
# Vous voilà employé de mairie. Vous devez gérer l'état civil.
#
# ### 2.1
# Créez la classe Date permettant de créer des dates et de les afficher. On ne vérifiera pas que le nombre de jours est correct par rapport au mois. Interdisez aux utilisateurs de modifier une date créée.

# %% [markdown]
# Ajoutez à votre classe une méthode de comparaison pour savoir si une date précède une autre.

# %% [markdown]
# ## 2.2
#
# Une personne possède un nom, un prénom et une date de naissance. Créez une classe qui permet de manipuler ces informations. En particulier, une personne doit être en mesure de modifier son nom.

# %% [markdown]
# Une personne peut être soit célibataire soit mariée. Si elle est mariée, la date du mariage est importante. Ajouter une méthode qui permet à deux personnes de se marier. On vérifiera dans la méthode que la date du mariage est postérieure à la naissance des deux personnes. Ajouter également une méthode permettant de savoir si la personne est mariée.

# %% [markdown]
# ## 2.3
#
# On ajoute maintenant la possibilité pour chaque individu d'avoir des parents. Ces parents sont optionnels au sens ou ils peuvent être inconnus.
#
# Codez une méthode qui permet de déterminer si la personne considérée est le frère ou la soeur d'une autre personne passée en paramètre (un seul parent commun suffit).

# %% [markdown]
# On considère désormais que les personnes sont soit des hommes, soit des femmes et que les hommes n'ont pas le droit de changer leur nom (vous êtes dans une mairie traditionnaliste). Faîtes les modifications appropriées.
